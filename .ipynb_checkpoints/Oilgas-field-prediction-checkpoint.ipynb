# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
test=pd.read_csv("oil_test.csv")
train=pd.read_csv("train_oil.csv")

# %%
test.head()
# Out:
#          Field name            Reservoir unit     Country  \
# 0      ABU GHARADIG                  BAHARIYA       EGYPT
# 1  ABU MADI-EL QARA      ABU MADI (LEVEL III)       EGYPT
# 2        ALIBEKMOLA                      KT I  KAZAKHSTAN
# 3       ALWYN NORTH        BRENT (BRENT EAST)          UK
# 4        ANKLESHWAR  ANKLESHWAR (HAZAD-ARDOL)       INDIA
#
#                 Region          Basin name  \
# 0               AFRICA        ABU GHARADIG
# 1               AFRICA          NILE DELTA
# 2  FORMER SOVIET UNION       CASPIAN NORTH
# 3               EUROPE  NORTH SEA NORTHERN
# 4             FAR EAST              CAMBAY
#
#                                      Tectonic regime  Latitude  Longitude  \
# 0                                          EXTENSION   29.7422    28.4925
# 1  STRIKE-SLIP/TRANSTENSION/SHALE/EVAPORITE/BASEM...   31.4382    31.3616
# 2                              COMPRESSION/EVAPORITE   48.4740    57.6667
# ...

# %%
train.head()
# Out:
#      Field name           Reservoir unit       Country               Region  \
# 0       ZHIRNOV              MELEKESKIAN        RUSSIA  FORMER SOVIET UNION
# 1   LAGOA PARDA  LAGOA PARDA (URUCUTUCA)        BRAZIL        LATIN AMERICA
# 2        ABQAIQ                   ARAB D  SAUDI ARABIA          MIDDLE EAST
# 3     MURCHISON                    BRENT    UK /NORWAY               EUROPE
# 4  WEST PEMBINA   NISKU (PEMBINA L POOL)        CANADA        NORTH AMERICA
#
#            Basin name        Tectonic regime  Latitude  Longitude  \
# 0          VOLGA-URAL  COMPRESSION/EVAPORITE   51.0000    44.8042
# 1      ESPIRITO SANTO              EXTENSION  -19.6017   -39.8332
# 2            THE GULF  COMPRESSION/EVAPORITE   26.0800    49.8100
# 3  NORTH SEA NORTHERN              EXTENSION   61.3833     1.7500
# 4      WESTERN CANADA            COMPRESSION   53.2287  -115.8008
#
#    Operator company Onshore/Offshore Hydrocarbon type      Reservoir status  \
# ...

# %%
print(train.shape,test.shape)
# Out:
# (309, 20) (133, 19)

# %%
print(train.isna().sum())
# Out:
# Field name                         0
# Reservoir unit                     0
# Country                           27
# Region                            38
# Basin name                        38
# Tectonic regime                    0
# Latitude                          27
# Longitude                         30
# Operator company                   0
# Onshore/Offshore                   0
# Hydrocarbon type                   0
# Reservoir status                   0
# Structural setting                 0
# Depth                              0
# Reservoir period                   0
# Lithology                          0
# Thickness (gross average ft)       0
# Thickness (net pay average ft)     0
# Porosity                           0
# Permeability                       0
# dtype: int64

# %%
print(test.isna().sum())
# Out:
# Field name                         0
# Reservoir unit                     0
# Country                           13
# Region                            16
# Basin name                         8
# Tectonic regime                    0
# Latitude                          13
# Longitude                         16
# Operator company                   0
# Hydrocarbon type                   0
# Reservoir status                   0
# Structural setting                 0
# Depth                              0
# Reservoir period                   0
# Lithology                          0
# Thickness (gross average ft)       0
# Thickness (net pay average ft)     0
# Porosity                           0
# Permeability                       0
# dtype: int64

# %%
plt.figure(figsize=(15,7))
cmap=sns.cubehelix_palette(as_cmap=True,light=.9)
sns.heatmap(train.isna().transpose(),cmap=cmap,cbar_kws={"label":"Missing Data"},linewidth=0.05)
# Out:
# <AxesSubplot:>

# %%
train.dtypes
# Out:
# Field name                         object
# Reservoir unit                     object
# Country                            object
# Region                             object
# Basin name                         object
# Tectonic regime                    object
# Latitude                          float64
# Longitude                         float64
# Operator company                   object
# Onshore/Offshore                   object
# Hydrocarbon type                   object
# Reservoir status                   object
# Structural setting                 object
# Depth                               int64
# Reservoir period                   object
# Lithology                          object
# Thickness (gross average ft)      float64
# Thickness (net pay average ft)    float64
# Porosity                          float64
# Permeability                      float64
# dtype: object

# %%
train=train.dropna()

# %%
plt.figure(figsize=(5,5))
train[["Latitude","Longitude","Depth","Porosity","Permeability"]].plot(kind="box")
# Out:
# <AxesSubplot:>

# %%
_,bp=train.Depth.plot.box(return_type="both",figsize=(6,6))

# %%
outliiners=[flier.get_ydata() for flier in bp["fliers"]][0]
train[train.Depth.isin(outliiners)]
# Out:
#        Field name                    Reservoir unit Country         Region  \
# 224   MILLS RANCH  HUNTON (CHIMNEY HILL-HENRYHOUSE)     USA  NORTH AMERICA
# 272  HATTERS POND                          NORPHLET     USA  NORTH AMERICA
#
#                           Basin name  \
# 224                         ANADARKO
# 272  GULF OF MEXICO NORTHERN ONSHORE
#
#                                        Tectonic regime  Latitude  Longitude  \
# 224                                COMPRESSION/EROSION   35.3676  -100.0793
# 272  GRAVITY/EXTENSION/EVAPORITE/DIAPIR/SYNSEDIMENT...   30.8976   -88.0660
#
#     Operator company Onshore/Offshore Hydrocarbon type      Reservoir status  \
# 224          CHEVRON          ONSHORE              GAS       NEARLY DEPLETED
# 272          CHEVRON          ONSHORE   GAS-CONDENSATE  DECLINING PRODUCTION
#
#       Structural setting  Depth Reservoir period  Lithology  \
# 224               THRUST  19888         SILURIAN   DOLOMITE
# ...

# %%
_,bp=train.Permeability.plot.box(return_type="both",figsize=(6,6))

# %%
outliiners=[flier.get_ydata() for flier in bp["fliers"]][0]
train[train.Permeability.isin(outliiners)]
# Out:
#             Field name                       Reservoir unit  \
# 4         WEST PEMBINA               NISKU (PEMBINA L POOL)
# 10         MENE GRANDE                               ISNOTU
# 14               ANGUS                           ANGUS SAND
# 43   LLOYDMINSTER AREA                               WASECA
# 47               BRAGE                            STATFJORD
# 67             MIDGARD                               FANGST
# 70               LANWA                                KALOL
# 78   LLOYDMINSTER AREA                               SPARKY
# 86          KADI NORTH                                KALOL
# 95              SERANG  BALIKPAPAN (UPPER DELTAIC SEQUENCE)
# 108             NASSER                               ZELTEN
# 110         BARRACOUTA                    LATROBE (M1 UNIT)
# 111              RAMBA                             BATURAJA
# 118           SUFFIELD             UPPER MANNVILLE (J POOL)
# 133              ETAME                                GAMBA
# ...

# %%
fig,axes=plt.subplots(2,2,figsize=(15,6))
sns.boxplot(train["Depth"],ax=axes[0,0],width=0.3)
sns.boxplot(train["Permeability"],ax=axes[0,1],width=0.3)
sns.boxplot(train["Porosity"],ax=axes[1,0],width=0.3)
sns.boxplot(train["Thickness (net pay average ft)"],ax=axes[1,1],width=0.3)
# Out:
# C:\Users\Msi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Msi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Msi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
plt.figure(figsize=(5,5))
sns.distplot(train["Depth"],bins=30)
# Out:
# C:\Users\Msi\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Depth', ylabel='Density'>

# %%
fig,axes=plt.subplots(2,2,figsize=(15,6))
sns.distplot(train["Depth"],ax=axes[0,0])
sns.distplot(train["Permeability"],ax=axes[0,1])
sns.distplot(train["Porosity"],ax=axes[1,0])
sns.distplot(train["Thickness (net pay average ft)"],ax=axes[1,1])
# Out:
# C:\Users\Msi\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Msi\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
sns.catplot(x="Onshore/Offshore",y="Depth",kind="box",data=train)

# %%
tmp = train[['Porosity', 'Permeability', 'Latitude', "Depth", 'Onshore/Offshore']]
sns.pairplot(tmp, hue = 'Onshore/Offshore')

# %%
train["Tectonic regime"].value_counts()
# Out:
# COMPRESSION                                                 57
# EXTENSION                                                   26
# COMPRESSION/EROSION                                         25
# COMPRESSION/EVAPORITE                                       18
# INVERSION/COMPRESSION/EXTENSION                             17
# EXTENSION/EROSION                                           12
# GRAVITY/EXTENSION/EVAPORITE                                 10
# COMPRESSION/EVAPORITE/EXTENSION/LINKED                       7
# GRAVITY/EXTENSION/EVAPORITE/SYNSEDIMENTATION                 7
# INVERSION/COMPRESSION/EXTENSION/EROSION                      7
# INVERSION/STRIKE-SLIP/TRANSPRESSION/EXTENSION/BASEMENT-I     5
# COMPRESSION/EXTENSION/LINKED                                 4
# GRAVITY/EVAPORITE/COMPRESSION                                4
# INVERSION/COMPRESSION/EXTENSION/EVAPORITE                    4
# GRAVITY/EVAPORITE/EXTENSION                                  4
# ...

# %%
train["Structural setting"].value_counts()
# Out:
# FORELAND                      67
# RIFT                          43
# INTRACRATONIC                 27
# THRUST                        14
# PASSIVE MARGIN                12
# SALT/FORELAND                 11
# SALT/PASSIVE MARGIN            9
# INVERSION/RIFT                 7
# DELTA/PASSIVE MARGIN           7
# INVERSION/BACKARC              6
# SALT/INVERSION/RIFT            5
# DELTA/SALT/PASSIVE MARGIN      5
# THRUST/FORELAND                4
# SUB-THRUST/FORELAND            4
# RIFT/SALT                      4
# RIFT/INVERSION                 3
# SUB-SALT/RIFT                  3
# SUB-SALT/FORELAND              3
# WRENCH                         3
# BACKARC                        3
# SALT/RIFT                      2
# FORELAND/SALT                  2
# FORELAND/THRUST                2
# THRUST/SUB-THRUST/FORELAND     2
# SUB-SALT/INVERSION             2
# SUB-THRUST                     2
# WRENCH/DELTA                   2
# SUB-SALT                       1
# ...

# %%
train["Basin name"].value_counts()
# Out:
# WESTERN CANADA                     24
# GULF OF MEXICO NORTHERN ONSHORE    19
# NORTH SEA CENTRAL                  14
# NORTH SEA NORTHERN                 12
# PERMIAN                            10
#                                    ..
# SIERRA GRANDE UPLIFT                1
# FORT WORTH                          1
# OTWAY                               1
# UINTA/PICEANCE                      1
# UINTA                               1
# Name: Basin name, Length: 92, dtype: int64

# %%
train=train.drop(columns=["Tectonic regime","Structural setting"])

# %%
train["Onshore/Offshore"].value_counts()
# Out:
# ONSHORE             187
# OFFSHORE             77
# ONSHORE-OFFSHORE      4
# Name: Onshore/Offshore, dtype: int64

# %%
categ = ['Hydrocarbon type', 'Reservoir status', 'Reservoir period', 'Lithology', 'Region']
for i in categ:
    print(i)
    print(set(test[i].unique()).difference(set(train[i].unique())))
# Out:
# Hydrocarbon type
# {'BITUMEN', 'METHANE HYDRATE'}
# Reservoir status
# set()
# Reservoir period
# {'CAMBRIAN-ORDOVICIAN/CARBONIFEROUS', 'ARCHEAN', 'CARBONIFEROUS-CRETACEOUS', 'PALEOZOIC-CRETACEOUS', 'PROTEROZOIC-CAMBRIAN', 'PERMIAN-TRIASSIC'}
# Lithology
# {'BASEMENT', 'CHERT', 'DIATOMITE', 'GLAUCONITIC SANDSTONE'}
# Region
# {nan}

# %%
from sklearn import preprocessing
le=preprocessing.LabelEncoder()
train["Onshore/Offshore"]=le.fit_transform(train["Onshore/Offshore"])
train.head()
# Out:
#      Field name           Reservoir unit       Country               Region  \
# 0       ZHIRNOV              MELEKESKIAN        RUSSIA  FORMER SOVIET UNION
# 1   LAGOA PARDA  LAGOA PARDA (URUCUTUCA)        BRAZIL        LATIN AMERICA
# 2        ABQAIQ                   ARAB D  SAUDI ARABIA          MIDDLE EAST
# 3     MURCHISON                    BRENT    UK /NORWAY               EUROPE
# 4  WEST PEMBINA   NISKU (PEMBINA L POOL)        CANADA        NORTH AMERICA
#
#            Basin name  Latitude  Longitude  Operator company  \
# 0          VOLGA-URAL   51.0000    44.8042  NIZHNEVOLZHSKNET
# 1      ESPIRITO SANTO  -19.6017   -39.8332         PETROBRAS
# 2            THE GULF   26.0800    49.8100      SAUDI ARAMCO
# 3  NORTH SEA NORTHERN   61.3833     1.7500               CNR
# 4      WESTERN CANADA   53.2287  -115.8008          NUMEROUS
#
#    Onshore/Offshore Hydrocarbon type      Reservoir status  Depth  \
# 0                 1              OIL  DECLINING PRODUCTION   1870
# ...

# %%
from sklearn import preprocessing
le=preprocessing.LabelEncoder()
train["Region"]=le.fit_transform(train["Region"])
train.head()
# Out:
#      Field name           Reservoir unit       Country  Region  \
# 0       ZHIRNOV              MELEKESKIAN        RUSSIA       3
# 1   LAGOA PARDA  LAGOA PARDA (URUCUTUCA)        BRAZIL       4
# 2        ABQAIQ                   ARAB D  SAUDI ARABIA       5
# 3     MURCHISON                    BRENT    UK /NORWAY       1
# 4  WEST PEMBINA   NISKU (PEMBINA L POOL)        CANADA       6
#
#            Basin name  Latitude  Longitude  Operator company  \
# 0          VOLGA-URAL   51.0000    44.8042  NIZHNEVOLZHSKNET
# 1      ESPIRITO SANTO  -19.6017   -39.8332         PETROBRAS
# 2            THE GULF   26.0800    49.8100      SAUDI ARAMCO
# 3  NORTH SEA NORTHERN   61.3833     1.7500               CNR
# 4      WESTERN CANADA   53.2287  -115.8008          NUMEROUS
#
#    Onshore/Offshore Hydrocarbon type      Reservoir status  Depth  \
# 0                 1              OIL  DECLINING PRODUCTION   1870
# 1                 1              OIL       NEARLY DEPLETED   4843
# ...

# %%
train=pd.get_dummies(train,columns=['Hydrocarbon type', 'Reservoir period', 'Lithology'])
train.head()
# Out:
#      Field name           Reservoir unit       Country  Region  \
# 0       ZHIRNOV              MELEKESKIAN        RUSSIA       3
# 1   LAGOA PARDA  LAGOA PARDA (URUCUTUCA)        BRAZIL       4
# 2        ABQAIQ                   ARAB D  SAUDI ARABIA       5
# 3     MURCHISON                    BRENT    UK /NORWAY       1
# 4  WEST PEMBINA   NISKU (PEMBINA L POOL)        CANADA       6
#
#            Basin name  Latitude  Longitude  Operator company  \
# 0          VOLGA-URAL   51.0000    44.8042  NIZHNEVOLZHSKNET
# 1      ESPIRITO SANTO  -19.6017   -39.8332         PETROBRAS
# 2            THE GULF   26.0800    49.8100      SAUDI ARAMCO
# 3  NORTH SEA NORTHERN   61.3833     1.7500               CNR
# 4      WESTERN CANADA   53.2287  -115.8008          NUMEROUS
#
#    Onshore/Offshore      Reservoir status  ...  Lithology_DOLOMITE  \
# 0                 1  DECLINING PRODUCTION  ...                   0
# 1                 1       NEARLY DEPLETED  ...                   0
# ...

# %%
sns.set(rc={"figure.figsize":(15,10)})
sns.heatmap(train.corr(),annot=False,cmap="YlGnBu",linecolor="white",linewidths=1)
# Out:
# <AxesSubplot:>
